# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
gss_data = pd.read_stata('GSS7216_R1a.dta', convert_categoricals=False)
gss_data.head()
# Out:
#    year  id  wrkstat  hrs1  hrs2  evwork    occ  prestige  wrkslf  wrkgovt  \
# 0  1972   1      1.0   NaN   NaN     NaN  205.0      50.0     2.0      NaN
# 1  1972   2      5.0   NaN   NaN     1.0  441.0      45.0     2.0      NaN
# 2  1972   3      2.0   NaN   NaN     NaN  270.0      44.0     2.0      NaN
# 3  1972   4      1.0   NaN   NaN     NaN    1.0      57.0     2.0      NaN
# 4  1972   5      7.0   NaN   NaN     1.0  385.0      40.0     2.0      NaN
#
#    ...   neisafe  rlooks  rgroomed  rweight  rhlthend  wtss  wtssnr  wtssall  \
# 0  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.4446
# 1  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
# 2  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
# 3  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
# 4  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0   0.8893
#
#    vstrat  vpsu
# 0     NaN   NaN
# 1     NaN   NaN
# ...

# %%
gss_data.set_index('id')
gss_data.drop('id', 1, inplace=True)
gss_data.head()
# Out:
#    year  wrkstat  hrs1  hrs2  evwork    occ  prestige  wrkslf  wrkgovt  \
# 0  1972      1.0   NaN   NaN     NaN  205.0      50.0     2.0      NaN
# 1  1972      5.0   NaN   NaN     1.0  441.0      45.0     2.0      NaN
# 2  1972      2.0   NaN   NaN     NaN  270.0      44.0     2.0      NaN
# 3  1972      1.0   NaN   NaN     NaN    1.0      57.0     2.0      NaN
# 4  1972      7.0   NaN   NaN     1.0  385.0      40.0     2.0      NaN
#
#    commute  ...   neisafe  rlooks  rgroomed  rweight  rhlthend  wtss  wtssnr  \
# 0      NaN  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0
# 1      NaN  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0
# 2      NaN  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0
# 3      NaN  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0
# 4      NaN  ...       NaN     NaN       NaN      NaN       NaN   1.0     1.0
#
#    wtssall  vstrat  vpsu
# 0   0.4446     NaN   NaN
# ...

# %%
gss_data['age'].hist(bins=25)
plt.grid()
plt.locator_params(nbins=5);

# %%
inc_age = gss_data[['realrinc','age']]
inc_age.head(10)
# Out:
#    realrinc   age
# 0       NaN  23.0
# 1       NaN  70.0
# 2       NaN  48.0
# 3       NaN  27.0
# 4       NaN  61.0
# 5       NaN  26.0
# 6       NaN  28.0
# 7       NaN  27.0
# 8       NaN  21.0
# 9       NaN  30.0

# %%
inc_age = gss_data[['realrinc','age']].dropna()
inc_age.head(10)
# Out:
#       realrinc   age
# 3117    4935.0  21.0
# 3118   43178.0  41.0
# 3121   18505.0  58.0
# 3122   22206.0  30.0
# 3123   55515.0  48.0
# 3126    4935.0  54.0
# 3131    4935.0  22.0
# 3132   18505.0  23.0
# 3137   11103.0  25.0
# 3142   30841.0  59.0

# %%
ax_list = inc_age.hist(bins=40, figsize=(8,3), xrot=45)
for ax in ax_list[0]:
    ax.locator_params(axis='x', nbins=6)
    ax.locator_params(axis='y', nbins=3)
